# %% [markdown]
# <a href="https://colab.research.google.com/github/surya333356/Capstone-Project-1_AirBnBb-Bookings-Analysis/blob/main/Airbnb_EDA_Project(SURYA_SINGH).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -**Airbnb Booking Analysis Exploratory Data Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual-SURYA SINGH

# %% [markdown]
# # **Project Summary -**
#
# Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.
#
# This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/surya333356/Capstone-Project-1_AirBnBb-Bookings-Analysis.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Lets Explore and analyze the Data Set and find some insights(Few Questions Listed Below)**
#
# 1.Which type of room/home is most preffered by the guests?
#
# 2.What can we learn about different hosts and areas?
#
# 3.What we learn from room type and their prices according to area?
#
# 4.What can we learn from Data?(ex:locations,prices,reviews,etc.)
#
# 5.Which hosts are the busiest and why is the reason?
#
# 6.Which hosts are charging higher price?
#
# 7.Is there any traffic difference among different areas and what could be the reason for it?
#
# 8.What is the correlation between different varriables?
#
# 9.What is the room count in overall NYC according to the listing of room types?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective for an Airbnb project centers on enhancing the platform's value proposition for both hosts and guests, ensuring a seamless, secure, and enjoyable experience.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import csv

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
path='/content/drive/MyDrive/Airbnb NYC 2019.csv'
# Out:
# Mounted at /content/drive

# %%
# Used to display all hidden columns
pd.set_option('display.max_columns',None)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb=pd.read_csv(path)
airbnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Creating a duplicate copy of original dataset before making any changes it
airbnb1=airbnb.copy()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
airbnb.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
airbnb1.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
# Plotting the heatmap
plt.figure(figsize=(12,6))
bar_plot=sns.heatmap(airbnb1.isna().transpose(),cmap='YlGnBu',cbar_kws={'label':'Missing Data'})
bar_plot.set_xlabel('Rows',color='red',fontsize=20)
bar_plot.set_ylabel('Columns',color='red',fontsize=20)
plt.title('Missing values',color='red',fontsize=25)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# We have some missing values.So we have to drop and replace them and clean the data for furthur analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb1.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe (Statistical data of columns)
airbnb1.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **id**: This is a unique identifier for each listing on Airbnb. It's used internally by Airbnb to distinguish between different listings.
#
# **name:** This column contains the name or title of the listing. It provides a brief description of the accommodation.
#
# **host_id:** Similar to the 'id' column, this is a unique identifier for each host who has listed their property on Airbnb. It allows Airbnb to associate listings with specific hosts.
#
# **host_name:** This column contains the name of the host who owns or manages the listing. It identifies the person responsible for the property.
#
# **neighbourhood_group:** This column indicates the larger geographical area or district in which the listing is located. It might represent neighborhoods grouped together for analysis or presentation purposes.
#
# **neighbourhood:** This column specifies the specific neighborhood or locality where the listing is situated. It provides more granular information about the location of the accommodation.
#
# **room_type:** This column describes the type of accommodation being offered, such as 'Entire home/apt', 'Private room', or 'Shared room'. It indicates whether the guest will have exclusive access to the entire property or will be sharing it with others.
#
# **price:** This column represents the nightly price (in the local currency) charged for renting the accommodation. It gives an indication of the cost of staying at the listing.
#
# **minimum_nights:** This column specifies the minimum number of nights a guest must book in order to stay at the listing. It indicates the host's policy regarding the duration of stays.
#
# **number_of_reviews:** This column indicates the total number of reviews that the listing has received from previous guests. It provides an indication of the popularity and possibly the quality of the accommodation.
#
# **calculated_host_listings_count:** This column shows the total number of listings managed by the host. It provides insight into the scale of the host's operation on Airbnb.
#
# **availability_365:** This column represents the number of days in a year for which the listing is available for booking. It provides information about the listing's availability throughout the year.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(airbnb1.apply(lambda col : col.unique()))
# Out:
# id                                [2539, 2595, 3647, 3831, 5022, 5099, 5121, 517...
# name                              [Clean & quiet apt home by the park, Skylit Mi...
# host_id                           [2787, 2845, 4632, 4869, 7192, 7322, 7356, 896...
# host_name                         [John, Jennifer, Elisabeth, LisaRoxanne, Laura...
# neighbourhood_group               [Brooklyn, Manhattan, Queens, Staten Island, B...
# neighbourhood                     [Kensington, Midtown, Harlem, Clinton Hill, Ea...
# latitude                          [40.64749, 40.75362, 40.80902, 40.68514, 40.79...
# longitude                         [-73.97237, -73.98377, -73.9419, -73.95976, -7...
# room_type                              [Private room, Entire home/apt, Shared room]
# price                             [149, 225, 150, 89, 80, 200, 60, 79, 135, 85, ...
# minimum_nights                    [1, 3, 10, 45, 2, 5, 4, 90, 7, 14, 60, 29, 30,...
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
airbnb1.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dropping the unnecessary columns
airbnb1.drop(['latitude','longitude','last_review','reviews_per_month'],axis=1,inplace=True)

# %%
# Handle Missing Values
airbnb1['name'].mode()
# Out:
# 0    Hillside Hotel
# Name: name, dtype: object

# %%
airbnb1['name'].fillna('Hillside Hotel',inplace=True)

# %%
airbnb1['host_name'].mode()
# Out:
# 0    Michael
# Name: host_name, dtype: object

# %%
airbnb1['host_name'].fillna('Michael',inplace=True)

# %%
# check missing value
airbnb1.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
# check columns
airbnb1.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Final look to check head and tail of dataset to analyze
airbnb1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
airbnb1.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood        room_type  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant     Private room
# 48891        Marisol            Brooklyn            Bushwick     Private room
# 48892  Ilgar & Aysel           Manhattan              Harlem  Entire home/apt
# 48893            Taz           Manhattan      Hell's Kitchen      Shared room
# 48894     Christophe           Manhattan      Hell's Kitchen     Private room
#
# ...

# %%
# Final check columns and rows
airbnb1.shape
# Out:
# (48895, 12)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Data Cleaning:
#
# Handling missing values: Identifying and dealing with missing values in the dataset, either by imputation or removal.
# Handling duplicates: Identifying and removing duplicate entries in the dataset.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### **Chart 1-** **Which type of room/home is most preffered by the guests?**

# %%
# Chart - 1 visualization code
room_types=airbnb1['room_type'].value_counts().reset_index()
room_types
# Out:
#          room_type  count
# 0  Entire home/apt  25409
# 1     Private room  22326
# 2      Shared room   1160

# %%
# Visualise the Data
# Plot the pie chart with explode and shadow
plt.figure(figsize=(8, 6))
plt.pie(room_types['count'], labels=room_types['room_type'],
        colors=['orange', 'green', 'blue'],
        autopct='%1.2f%%',
        startangle=10,
        explode=[0, 0.1, 0.1],
        shadow=True, textprops={'fontsize': 14})

# Set the title
plt.title('Type of room/home most preferred by the guests', color='red', fontsize=20)

# Customize the legend
legend = plt.legend(room_types['room_type'], title='Room Types', loc='center left', bbox_to_anchor=(1, 0.5, 0.5, 0.5))
plt.setp(legend.get_title(), color='red')  # Change legend title color
legend.get_frame().set_facecolor('cyan')  # Change legend background color

# Display the pie chart
plt.show()

# %% [markdown]
# **Insight:-** **Entire home/apt** is the most preferred room type with **51.97%** of the total bookings, indicating that nearly half of the guests prefer to book an entire home or apartment.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This pie chart give you a clear and easy-to-interpret visual representation of the number of bookings by room type. and shows in percentage the analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Entire home/apt** is the most preferred room type with **51.97%** of the total bookings, indicating that nearly half of the guests prefer to book an entire home or apartment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# To create a positive business impact, businesses should leverage the popularity of **entire homes/apartments** and **private rooms** by investing in these areas and tailoring their marketing and pricing strategies accordingly.

# %% [markdown]
# #### **Chart 2-** **What can we learn about different hosts and areas?**

# %%
host_areas=airbnb1.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].sum().reset_index()
host_areas=host_areas.sort_values(by='calculated_host_listings_count',ascending=False).head(10)
host_areas
# Out:
#                host_name neighbourhood_group  calculated_host_listings_count
# 13217       Sonder (NYC)           Manhattan                          106929
# 1834          Blueground           Manhattan                           53360
# 7275                Kara           Manhattan                           14669
# 6540      Jeremy & Laura           Manhattan                            9216
# 13216             Sonder           Manhattan                            9216
# 2901   Corporate Housing           Manhattan                            8281
# 7480              Kazuya              Queens                            8137
# 7546                 Ken           Manhattan                            7500
# 11399            Pranjal           Manhattan                            4225
# 9856                Mike           Manhattan                            2824

# %%
# Plot the barplot
plt.figure(figsize=(12, 6))
bar_plot = sns.barplot(data=host_areas, x='host_name', y='calculated_host_listings_count',
                       hue='neighbourhood_group', palette='bright', width=0.5)

# Set the labels and title
bar_plot.set_xlabel('Host Name', color='red',fontsize=16)
bar_plot.set_ylabel('Listings Count', color='red',fontsize=16)
bar_plot.set_title('Host Listings Count by Neighbourhood Group', color='red',fontsize=20)

# Add the value labels on the bars with markers
for p in bar_plot.patches:
    bar_plot.annotate(f'{int(p.get_height())}',
                      (p.get_x() + p.get_width() / 2., p.get_height()),
                      ha='center', va='center',
                      xytext=(0, 9),
                      textcoords='offset points')

# Customize the plot
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# **Insight:-**We find that Host name **Sonder(NYC)** has listed highest number of listings in **Manhattan** followed by **Blueground** and maximum property is listed in **Manhattan**.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are straightforward and easy to read. They clearly display differences in quantities among different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We find that Host name **Sonder(NYC)** has listed highest number of listings in **Manhattan** followed by **Blueground** and maximum property is listed in **Manhattan**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **positive business impact:-** This indicates a strong market presence and could suggest that investing more in marketing and partnerships in Manhattan could yield high returns. Other hosts might learn from Sonder’s strategies to increase their listings.
#
# **negative growth:-** This could indicate market saturation in Manhattan, leading to increased competition and potentially lower occupancy rates or prices. Hosts may face diminishing returns if the market is too crowded, suggesting a need to explore less saturated neighbourhoods.

# %% [markdown]
# #### **Chart 3-** **What we learn from room type and their prices according to area?**

# %%
room_price_areawise=airbnb1.groupby(['neighbourhood_group','room_type'])['price'].max().reset_index()
room_price_areawise=room_price_areawise.sort_values(by='price',ascending=False).head(10)
room_price_areawise
# Out:
#    neighbourhood_group        room_type  price
# 3             Brooklyn  Entire home/apt  10000
# 6            Manhattan  Entire home/apt  10000
# 10              Queens     Private room  10000
# 7            Manhattan     Private room   9999
# 4             Brooklyn     Private room   7500
# 12       Staten Island  Entire home/apt   5000
# 9               Queens  Entire home/apt   2600
# 1                Bronx     Private room   2500
# 11              Queens      Shared room   1800
# 0                Bronx  Entire home/apt   1000

# %%
# Create bar plot
plt.figure(figsize=(10, 5))
sns.barplot(x='neighbourhood_group', y='price', hue='room_type',palette='bright', data=room_price_areawise, errorbar=None,width=0.8)
plt.title('Average Price by Neighbourhood Group and Room Type',color='red',fontsize=20)
plt.ylabel('Average Price',color='red',fontsize=15)
plt.xlabel('Neighbourhood Group',color='red',fontsize=15)
plt.legend(title='Room Type')
plt.grid(axis='y')
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:-** Overall, the chart provides a visual representation of how prices vary across different neighborhood groups and room types.In **Brooklyn** area has maximum price and types of rooms are **Entire home/apt**.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I suggested creating a bar plot because you seem to have categorical data (neighborhood group and room type) and want to visualize the average price for each category combination. Bar plots are a common choice for visualizing categorical data,

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Overall, the chart provides a visual representation of how prices vary across different neighborhood groups and room types.In **Brooklyn** area has maximum price and types of rooms are **Entire home/apt**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive business impact:-** in the hospitality industry, such as Airbnb hosts or hotel operators, can use the insights to adjust their pricing strategies based on the demand and competition in different neighborhood groups and for different room types. They can set competitive prices to attract more guests while maximizing revenue.
#
# **Negative growth:-**Continuously overpricing accommodations relative to their value in a specific neighborhood can lead to negative reviews and a tarnished reputation. This can deter potential guests and lead to long-term negative growth as word-of-mouth spreads.

# %% [markdown]
# #### Chart - 4
#
# **What can we learn from Data?(ex:locations,prices,reviews,etc.)**

# %%
area_reviews=airbnb1.groupby(['neighbourhood_group'])['number_of_reviews'].sum().reset_index()
area_reviews=area_reviews.sort_values(by='number_of_reviews',ascending=False)
area_reviews
# Out:
#   neighbourhood_group  number_of_reviews
# 1            Brooklyn             486574
# 2           Manhattan             454569
# 3              Queens             156950
# 0               Bronx              28371
# 4       Staten Island              11541

# %%
plt.figure(figsize=(12, 5))
bar_plot = sns.barplot(data=area_reviews, x='neighbourhood_group', y='number_of_reviews',hue='neighbourhood_group', palette='bright', width=0.5)
bar_plot.set_xlabel('Area', color='red',fontsize=16)
bar_plot.set_ylabel('Reviews', color='red',fontsize=16)
bar_plot.set_title('Number of Reviews vs. Area', color='red',fontsize=20)
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:-** In **Brooklyn** area has maximum reviews

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plots make it easy to see differences in the number of reviews between neighborhood groups by representing the data with vertical bars. Each bar represents a neighborhood group, and the height of the bar corresponds to the number of reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In **Brooklyn** area has maximum reviews

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While the insights gained from the bar plot can provide valuable information for businesses to improve their operations and drive positive growth, it's essential for businesses to consider the nuances of the data and take a holistic approach to decision-making. This includes addressing both positive and negative insights to maximize opportunities and mitigate potential risks.

# %% [markdown]
# #### **Chart - 5**

# %%
price_area=airbnb1.groupby(['price'])['number_of_reviews'].sum().reset_index()
price_area=price_area.sort_values(by='number_of_reviews',ascending=False).head(10)
price_area
# Out:
#      price  number_of_reviews
# 89     100              40293
# 139    150              36196
# 49      60              32096
# 54      65              30292
# 64      75              29590
# 39      50              29069
# 69      80              28313
# 88      99              27745
# 114    125              27180
# 109    120              27055

# %%
plt.figure(figsize=(12,5))
scatter_plot=sns.scatterplot(data=price_area,x='price',y='number_of_reviews',hue='price',palette='bright')
scatter_plot.set_xlabel('Price',color='red',fontsize=16)
scatter_plot.set_ylabel('Reviews',color='red',fontsize=16)
scatter_plot.set_title('Number of Reviews VS Price',color='red',fontsize=20)
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:-** From above visualization we can say that **most number of people** like to say in **less price** and their **reviews are higher** in those areas.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is a suitable choice for exploring the relationship between two continuous variables and gaining insights into their association.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above visualization we can say that most number of people like to say in less price and their reviews are higher in those areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While the insights gained from the scatter plot can inform pricing strategies and improve business performance, it's essential for businesses to carefully consider and act upon these insights to avoid potential negative growth outcomes and capitalize on revenue opportunities.

# %% [markdown]
# #### Chart - 6
#
# **Which hosts are the busiest and why is the reason?**

# %%
busy_hosts=airbnb1.groupby(['host_id','host_name','room_type'])['number_of_reviews'].sum().reset_index()
busy_hosts=busy_hosts.sort_values(by='number_of_reviews',ascending=False).head(10)
busy_hosts
# Out:
#         host_id                       host_name     room_type  \
# 22225  37312959                            Maya  Private room
# 1117     344035  Brooklyn&   Breakfast    -Len-  Private room
# 21775  35524316                    Yasu & Akiko  Private room
# 22872  40176101                           Brady  Private room
# 7710    4734398                              Jj  Private room
# 19453  26432133                        Danielle  Private room
# 15379  16677326                  Alex And Zeena  Private room
# 9630    6885157                           Randy  Private room
# 18297  23591164                          Angela  Private room
# 26515  59529529                             Han  Private room
#
#        number_of_reviews
# 22225               2273
# 1117                2205
# 21775               1837
# 22872               1818
# 7710                1798
# 19453               1793
# 15379               1355
# 9630                1323
# 18297               1269
# ...

# %%
plt.figure(figsize=(12,5))
bar_plot=sns.barplot(data=busy_hosts,x='host_name',y='number_of_reviews',palette='bright',hue='room_type',width=0.5)
bar_plot.set_xlabel('Name of the Host',color='red',fontsize=16)
bar_plot.set_ylabel('Reviews',color='red',fontsize=16)
bar_plot.set_title('Busiest host in terms of Reviews',color='red',fontsize=20)
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:-** **We have found busiest hosts**:- **Maya**, **Brooklyn& Breakfast -Len**, **Yasu & Akiko**,
# **Brady**, **Jj**
# Because these hosts listed their room types as **private room** which is preferred by most number of people and also higher reviews.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This bar graph is used for better visualisation between categarical and numerical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **We have found busiest hosts**
#
# 1.**Maya**
#
# 2.**Brooklyn& Breakfast -Len**
#
# 3.**Yasu & Akiko**
#
# 4.**Brady**
#
# 5.**Jj**
#
# Because these hosts listed their room types as **private room** which is preferred by most number of people and also higher reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Understanding Room Type Preferences:**
#
#  The data includes the number of reviews for each room type, which can help businesses understand the preferences of their customers. This insight can inform marketing strategies, pricing decisions, and inventory management to better meet customer demand and increase overall satisfaction.
#
# ** Disregarding Customer Feedback:**
#
# Ignoring patterns or common issues identified in customer reviews can lead to persistent problems that negatively impact the business's reputation and growth. Failing to address customer feedback may result in decreased customer satisfaction, increased negative reviews, and loss of potential customers.

# %% [markdown]
# #### **Chart 7-** **Which hosts are charging higher price?**

# %%
highest_price=airbnb1.groupby(['host_id','host_name','neighbourhood_group','room_type'])['price'].max().reset_index()
highest_price=highest_price.sort_values(by='price',ascending=False).head(10)
highest_price
# Out:
#          host_id host_name neighbourhood_group        room_type  price
# 8058     5143901      Erin            Brooklyn  Entire home/apt  10000
# 27933   72390391    Jelena           Manhattan  Entire home/apt  10000
# 17067   20582832  Kathrine              Queens     Private room  10000
# 2662     1235070     Olson           Manhattan  Entire home/apt   9999
# 7328     4382127      Matt           Manhattan  Entire home/apt   9999
# 6631     3906464       Amy           Manhattan     Private room   9999
# 16103   18128455       Rum           Manhattan  Entire home/apt   8500
# 2564     1177497   Jessica            Brooklyn  Entire home/apt   8000
# 33439  156158778     Sally           Manhattan  Entire home/apt   7703
# 10118    7407743      Jack           Manhattan  Entire home/apt   7500

# %%
plt.figure(figsize=(12,5))
bar_plot=sns.barplot(data=highest_price,x='host_name',y='price',palette='bright',hue='host_name',width=0.5)
bar_plot.set_xlabel('Name of the Host',color='red',fontsize=16)
bar_plot.set_ylabel('Price',color='red',fontsize=16)
bar_plot.set_title('Hosts with maximum price charges',color='red',fontsize=20)
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:-** **Now we have seen that top 10 hosts who are charging maximum price:-**
# **Erin,Jelena,Kathrine,Olson,Matt,Amy,Rum,Jessica,Sally,Jack**
#
# Max Price is **10000 USD**

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is easy to understand and clearly visualise.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Now we have seen that top 10 hosts who are charging maximum price:-**
#
# **Erin,Jelena,Kathrine,Olson,Matt,Amy,Rum,Jessica,Sally,Jack**
#
# Max Price is **10000 USD**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:** Optimized Pricing Strategy,Identifying High-Demand Areas,Understanding Room Type Preferences.
#
# **Negative Growth Potential:** Overpricing and Neglecting Room Type Preferences: Businesses that ignore customer preferences for specific room types may experience decreased customer satisfaction and repeat bookings. Failing to offer the desired accommodation types can result in lost revenue and a negative impact on overall growth.

# %% [markdown]
# #### **Chart 8-** **Is there any traffic difference among different areas and what could be the reason for it?**

# %%
traffic_areas=airbnb1.groupby(['neighbourhood_group','room_type'])['minimum_nights'].sum().reset_index()
traffic_areas=traffic_areas.sort_values(by='minimum_nights',ascending=False).head(10)
traffic_areas
# Out:
#    neighbourhood_group        room_type  minimum_nights
# 6            Manhattan  Entire home/apt          139108
# 3             Brooklyn  Entire home/apt           62433
# 4             Brooklyn     Private room           56126
# 7            Manhattan     Private room           43477
# 10              Queens     Private room           17265
# 9               Queens  Entire home/apt           11255
# 8            Manhattan      Shared room            3248
# 5             Brooklyn      Shared room            3202
# 1                Bronx     Private room            2516
# 0                Bronx  Entire home/apt            2258

# %%
# Plot the bar chart
plt.figure(figsize=(12, 5))
sns.barplot(x='neighbourhood_group', y='minimum_nights', hue='room_type', data=traffic_areas, palette='bright')
plt.xlabel('Neighbourhood Group',color='red', fontsize=16)
plt.ylabel('Minimum Nights', color='red',fontsize=16)
plt.title('Minimum Nights Required by Neighbourhood Group and Room Type',color='red', fontsize=20)
plt.legend(title='Room Type',fontsize=12)
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:-** **Observation:** Manhattan has significantly higher minimum nights required for both **'Entire home/apt'** and **'Private room'** categories.
#
# **Reason:** This could be due to the high demand and premium nature of properties in **Manhattan**. Hosts in Manhattan might set higher minimum nights to ensure longer stays, thereby reducing turnover and administrative efforts.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plot is easy to understand between catagarical data and numeric data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Observation:**
# **Manhattan** has significantly higher minimum nights required for both **'Entire home/apt'** and **'Private room'** categories.
#
# **Reason:**
# This could be due to the high demand and premium nature of properties in Manhattan. Hosts in Manhattan might set higher minimum nights to ensure longer stays, thereby reducing turnover and administrative efforts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While the insights gained from the data can inform minimum nights policies and help businesses optimize revenue generation and customer satisfaction, it's essential for businesses to carefully consider and address potential pitfalls, such as overly restrictive policies or misalignment with demand trends, to avoid negative growth outcomes. Adjusting minimum nights policies based on guest preferences and market dynamics can help businesses achieve positive business impacts and maintain competitiveness in the hospitality industry.

# %% [markdown]
# #### **Chart - 9 - Correlation Heatmap**

# %%
corr1=airbnb1.select_dtypes(include=['int64','float64'])
corr1.corr()
# Out:
#                                       id   host_id     price  minimum_nights  \
# id                              1.000000  0.588290  0.010619       -0.013224
# host_id                         0.588290  1.000000  0.015309       -0.017364
# price                           0.010619  0.015309  1.000000        0.042799
# minimum_nights                 -0.013224 -0.017364  0.042799        1.000000
# number_of_reviews              -0.319760 -0.140106 -0.047954       -0.080116
# calculated_host_listings_count  0.133272  0.154950  0.057472        0.127960
# availability_365                0.085468  0.203492  0.081829        0.144303
#
#                                 number_of_reviews  \
# id                                      -0.319760
# host_id                                 -0.140106
# price                                   -0.047954
# minimum_nights                          -0.080116
# number_of_reviews                        1.000000
# ...

# %%
fig = plt.figure(figsize=(12, 5))
sns.heatmap(corr1.corr(), annot=True, cmap='YlGnBu')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.title('Correlation Matrix', fontsize=16, color='red')
plt.show()

# %% [markdown]
# **Insight:-** you can see that the number of reviews has a negative correlation with the ID and calculated_host_listings_count variables, indicating that as one increases, the other decreases. On the other hand, it has a positive correlation with availability_365, suggesting that more availability throughout the year might lead to more reviews.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation matrices are particularly helpful because they allow you to quickly see how strongly or weakly variables are related to each other. This information can be crucial for understanding which variables might influence each other and how changes in one variable might affect others.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# you can see that the number of reviews has a negative correlation with the ID and calculated_host_listings_count variables, indicating that as one increases, the other decreases. On the other hand, it has a positive correlation with availability_365, suggesting that more availability throughout the year might lead to more reviews.

# %% [markdown]
# #### Chart - 10 - Pair Plot

# %%
# Sample the data
sample_data = airbnb1.sample(n=500, random_state=42)

# Set the bright color palette
sns.set_palette('bright')

# Create the pairplot
sns.pairplot(sample_data, vars=['price', 'number_of_reviews'], hue='neighbourhood_group', kind='scatter', height=5, aspect=1.5)
plt.show()

# %% [markdown]
# **Insight:-** The pairplot provides a comprehensive visual summary of the relationships between price, number of reviews, neighborhood groups, and room types, allowing for complexities insights into factors influencing accommodation popularity and pricing in the Airbnb dataset. For example, you can see if certain room types are more popular or receive more reviews in specific neighborhoods.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pairplot is a convenient way to create pairwise scatterplots for multiple variables in your dataset, allowing you to quickly assess the relationships between variables and identify any patterns or trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pairplot provides a comprehensive visual summary of the relationships between price, number of reviews, neighborhood groups, and room types, allowing for complexities insights into factors influencing accommodation popularity and pricing in the Airbnb dataset.
# For example, you can see if certain room types are more popular or receive more reviews in specific neighborhoods.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
#  **1. Focus on Private Rooms
# Reasoning:** Private rooms have the highest number of reviews, indicating strong demand.
#
# **Action:** Increase the inventory of private rooms or optimize existing private room listings to attract more guests.
#
#  **2. Optimize Entire Home/Apt Listings
# Reasoning:** Entire homes/apartments also have maximum bookings and a significant number of reviews, indicating good demand but less than private rooms.
#
# **Action:** Highlight unique features, privacy, and the convenience of having an entire space to oneself. Consider competitive pricing and flexible check-in/check-out options to attract more bookings.
#
#  **3. Reassess Shared Room Offerings
# Reasoning:** Shared rooms have the lowest number of reviews, suggesting lower demand.
#
# **Action:** Evaluate the profitability of shared room listings. Consider if they are worth maintaining or if resources could be better allocated to other room types. If continuing with shared rooms, consider enhancing the value proposition, such as improved privacy measures, better amenities, or lower prices.
#
#  **4. Enhance Customer Experience
# Action:**
#
# **Improve facilities:** Ensure that all types of accommodations have high-quality facilities that meet guest expectations.
#
# **Personal Touch:** Provide personalized touches like welcome packages, local guides, or special offers for repeat guests.
#
# **Responsive Communication:** Maintain excellent communication with guests before, during, and after their stay to enhance their experience and encourage positive reviews.
#
#  **5.Reviews for Marketing
# Action:**
#
# **Showcase Positive Reviews:** Highlight positive reviews in listings to build trust and attract more bookings.
#
# **Address Feedback:** Respond to negative feedback constructively and implement improvements based on guest suggestions.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. **Entire home/apt** is the most preferred room type with **51.97%** of the total bookings, indicating that nearly half of the guests prefer to book an **entire home or apartment**.
#
# 2. We find that Host name **Sonder(NYC)** has listed highest number of listings in **Manhattan** followed by **Blueground** and maximum property is listed in **Manhattan**.
#
# 3. We found that **Entire home/apt** is the highest number of room types overall and prices are high in the **Brooklyn** and **Manhattan** for entire home/apt.
#
# 4. From above visualization we can say that most number of people like to stay in less price and their reviews are higher in those areas.
#
# 5. We have found busiest hosts:- **Maya, Brooklyn& Breakfast -Len, Yasu & Akiko, Brady, Jj** Because these hosts listed their room types as **private room** which is preferred by most number of people and also higher reviews.
#
# 6. Now we have seen that 10 Hosts who are charging maximum price :- **Erin,Jelena,
#  Kathrine,Olson,Matt,Amy,Rum,Jessica,Sally,Jack**
#
#  Max Price is **10000 USD**
#
# 7. From the visualization we found that most of the people likely to stay at **Entire home and Private room** which are present in **Manhattan**,**Brooklyn** and **Queens** and also visitors reffering stay in room which listing price is less.
#
# 8. We have seen all the correlation between different variables.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
